# %% [markdown]
# ### In this notebook we explore the potential for extracting text from the audio files that can be used to find addresses and other important words and phrases.

# %% [markdown]
# #### A potential API for taking partial address information and cross-referencing it with known addresses
# https://smartystreets.com/products/apis/us-autocomplete-api

# %%
# general packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# packages toward nlp

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# import the csv's as dataframes

df0 = pd.read_csv('3_dataframes/df_speech_recognition.csv')        # filename
df1 = pd.read_csv('3_dataframes/df_newspeech_recognition.csv')

# %% [markdown]
# <font color = blue>Exploring the dataframes</font>

# %%
df0.shape
# Out:
# (2898, 4)

# %%
df1.shape
# Out:
# (1470, 4)

# %%
df0.head()
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  /home/ubuntu/audio_files/Neal Manahan - negati...
# 1           1  /home/ubuntu/audio_files/Neal Manahan - negati...
# 2           2  /home/ubuntu/audio_files/Neal Manahan - negati...
# 3           3  /home/ubuntu/audio_files/Neal Manahan - negati...
# 4           4  /home/ubuntu/audio_files/Neal Manahan - negati...
#
#   good_exception audio_recognition
# 0      Exception               NaN
# 1      Exception               NaN
# 2      Exception               NaN
# 3      Exception               NaN
# 4      Exception               NaN

# %%
df1.head()
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  /home/ubuntu/new_audios/Neal Manahan - negativ...
# 1           1  /home/ubuntu/new_audios/Neal Manahan - negativ...
# 2           2  /home/ubuntu/new_audios/Neal Manahan - negativ...
# 3           3  /home/ubuntu/new_audios/Neal Manahan - negativ...
# 4           4  /home/ubuntu/new_audios/Neal Manahan - negativ...
#
#   good_exception                                  audio_recognition
# 0      Exception                                                NaN
# 1           Good  the district maybe we can get a hold of them W...
# 2           Good                                      West Virginia
# 3      Exception                                                NaN
# 4      Exception                                                NaN

# %% [markdown]
# <font color = blue>Merging the dataframe from both cases into one dataframe.</font>

# %%
df = pd.concat([df0, df1], axis=0)
df.head()
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  /home/ubuntu/audio_files/Neal Manahan - negati...
# 1           1  /home/ubuntu/audio_files/Neal Manahan - negati...
# 2           2  /home/ubuntu/audio_files/Neal Manahan - negati...
# 3           3  /home/ubuntu/audio_files/Neal Manahan - negati...
# 4           4  /home/ubuntu/audio_files/Neal Manahan - negati...
#
#   good_exception audio_recognition
# 0      Exception               NaN
# 1      Exception               NaN
# 2      Exception               NaN
# 3      Exception               NaN
# 4      Exception               NaN

# %%
df.shape
# Out:
# (4368, 4)

# %%
# dropping the 'Unnamed: 0' column

df.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# <font color = blue>Building a class column in the dataframe.</font>

# %%
df.file_name[0]
# Out:
# 0    /home/ubuntu/audio_files/Neal Manahan - negati...
# 0    /home/ubuntu/new_audios/Neal Manahan - negativ...
# Name: file_name, dtype: object

# %%
pd.options.display.max_columns = 500

# %%
print(df.file_name[0])
# Out:
# 0    /home/ubuntu/audio_files/Neal Manahan - negati...
# 0    /home/ubuntu/new_audios/Neal Manahan - negativ...
# Name: file_name, dtype: object

# %%
# resetting the index in the dataframe

df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                                            file_name good_exception  \
# 0  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 1  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 2  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 3  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 4  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
#
#   audio_recognition
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.shape
# Out:
# (4368, 3)

# %%
df.tail()
# Out:
#                                               file_name good_exception  \
# 4363  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4364  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4365  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4366  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4367  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
#
#                                       audio_recognition
# 4363                           argument with girlfriend
# 4364                                                NaN
# 4365                                          call Papa
# 4366  Piedmont North Haledon all secure no vehicle m...
# 4367                 and I was at Piedmont North Hilton

# %%
df.file_name[0]
# Out:
# '/home/ubuntu/audio_files/Neal Manahan - negative_baton_rouge_1_-01.wav'

# %%
type(df.file_name[0])
# Out:
# str

# %%
# building a dataframe with only five rows

test_df = df.loc[:5]

# %%
test_df
# Out:
#                                            file_name good_exception  \
# 0  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 1  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 2  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 3  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 4  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 5  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
#
#   audio_recognition
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN

# %%
test_df['class'] = df.file_name.apply(lambda x: 0 if 'negative' in x else 1)
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_df.head()
# Out:
#                                            file_name good_exception  \
# 0  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 1  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 2  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 3  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
# 4  /home/ubuntu/audio_files/Neal Manahan - negati...      Exception
#
#   audio_recognition  class
# 0               NaN      0
# 1               NaN      0
# 2               NaN      0
# 3               NaN      0
# 4               NaN      0

# %%
df['class'] = df.file_name.apply(lambda x: 0 if 'negative' in x else 1)

# %%
pd.options.display.max_rows = 100

# %%
df.tail(100)
# Out:
#                                               file_name good_exception  \
# 4268  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4269  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4270  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4271  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4272  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4273  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4274  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4275  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4276  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4277  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4278  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4279  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4280  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4281  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4282  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4283  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4284  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4285  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4286  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4287  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4288  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4289  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4290  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4291  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4292  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4293  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4294  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4295  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4296  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4297  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4298  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4299  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4300  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4301  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4302  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4303  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4304  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4305  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4306  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4307  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4308  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4309  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4310  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4311  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4312  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4313  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4314  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4315  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4316  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4317  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4318  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4319  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4320  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4321  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4322  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4323  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4324  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4325  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4326  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4327  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4328  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4329  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4330  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4331  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4332  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4333  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4334  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4335  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4336  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4337  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4338  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4339  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4340  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4341  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4342  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4343  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4344  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4345  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4346  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4347  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4348  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4349  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4350  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4351  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4352  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4353  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4354  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4355  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4356  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4357  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4358  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4359  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4360  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4361  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4362  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4363  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4364  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...      Exception
# 4365  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4366  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 4367  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
#
#                                       audio_recognition  class
# 4268                                                NaN      1
# 4269                                                NaN      1
# 4270                                   can I get stolen      1
# 4271                                                NaN      1
# 4272                         breathing looks like maybe      1
# 4273                                                NaN      1
# 4274  call Judith all-district N64 the following ann...      1
# 4275               contact the White Center to 640-2209      1
# 4276                                         Channel 43      1
# 4277                                   Charlie one five      1
# 4278                                                 12      1
# 4279                                            Sephora      1
# 4280                                                NaN      1
# 4281                                Guardian man Horton      1
# 4282                                               Zuri      1
# 4283                                                NaN      1
# 4284                                     733 Ontario 31      1
# 4285                                                NaN      1
# 4286  OK Google will advisors Angela find out what's...      1
# 4287                                                NaN      1
# 4288                                                NaN      1
# 4289                                                NaN      1
# 4290                         45 W 60th Mile and Gratiot      1
# 4291  number one female Hospital from 1111 Fulton Co...      1
# 4292                                                NaN      1
# 4293  viruses going today. The second one for a beau...      1
# 4294                                             Turn 4      1
# 4295                         volume for the alarm alarm      1
# 4296                                                NaN      1
# 4297                                                NaN      1
# 4298                              Closter 2288 forklift      1
# 4299                                  cuz I got 130 KJR      1
# 4300                                         handle 511      1
# 4301  yes and just be advised this has no affiliatio...      1
# 4302                                              Opera      1
# 4303                                         Sai temple      1
# 4304  Franklin 44140 West Lafayette Kiara Mason at t...      1
# 4305                   5300 block of Cordelia softlayer      1
# 4306                                   West 26th Street      1
# 4307                                                NaN      1
# 4308                                                NaN      1
# 4309                          temperature is what it is      1
# 4310                                                NaN      1
# 4311                        restaurants on 207th Street      1
# 4312             and 200 West Baltimore is THC Pharmacy      1
# 4313                                            traffic      1
# 4314  assassin for an officer somebody is threatenin...      1
# 4315                                                 24      1
# 4316                                                NaN      1
# 4317                                         picture of      1
# 4318                                               45 m      1
# 4319                                 weather show today      1
# 4320                                  300 North Charles      1
# 4321      Adderall use on 1 2 switch back to back today      1
# 4322                                  118 North Highway      1
# 4323                                                NaN      1
# 4324                                      Weimar Street      1
# 4325                                       3 North Road      1
# 4326                                                NaN      1
# 4327  320 York Road from 320 York Road for the armed...      1
# 4328                        welcome right back out back      1
# 4329                                  Crayola clear now      1
# 4330           I was up here you say that the day today      1
# 4331                                                NaN      1
# 4332                                   16 North Holland      1
# 4333    I'm just inquiring if I had 2779 with dyspepsia      1
# 4334     Cloud over head to our old whose address again      1
# 4335                                                NaN      1
# 4336                           05 everything okay there      1
# 4337                                                NaN      1
# 4338                                       MP3 download      1
# 4339  I just want to sex living in Glen Oaks very li...      1
# 4340  reckless driver in the parking lot to New Orle...      1
# 4341                                                NaN      1
# 4342                              Fairview and Garrison      1
# 4343                                                NaN      1
# 4344                                                NaN      1
# 4345                                                NaN      1
# 4346                                           lingerie      1
# 4347  signal 30 at Moravia and Cold Springs also Har...      1
# 4348                                                NaN      1
# 4349                                        Tim Hortons      1
# 4350                                         2016 worth      1
# 4351                                                 26      1
# 4352        down for anything change East Baltimore 409      1
# 4353                                                NaN      1
# 4354                                       782-277-9779      1
# 4355                                                NaN      1
# 4356          6011 cedonia unknown travel from anywhere      1
# 4357                                              Tupac      1
# 4358                                                NaN      1
# 4359                                                NaN      1
# 4360                                                NaN      1
# 4361                                                NaN      1
# 4362                                                NaN      1
# 4363                           argument with girlfriend      1
# 4364                                                NaN      1
# 4365                                          call Papa      1
# 4366  Piedmont North Haledon all secure no vehicle m...      1
# 4367                 and I was at Piedmont North Hilton      1

# %%
df['class'].value_counts()
# Out:
# 0    3457
# 1     911
# Name: class, dtype: int64

# %%
df[df['good_exception'] == 'Good'].shape
# Out:
# (1035, 4)

# %%
df_text = df[df['good_exception'] == 'Good']
df_text.head()
# Out:
#                                             file_name good_exception  \
# 11  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 15  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 31  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 40  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 51  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
#
#                                     audio_recognition  class
# 11                                               3425      0
# 15  phone number for Direct Control of Kendall Street      0
# 31                                  20174 Perrysville      0
# 40                                            Medical      0
# 51                                p1191 Hyundai sedan      0

# %%
df_text['class'].value_counts()
# Out:
# 0    661
# 1    374
# Name: class, dtype: int64

# %%
df_text['class'].value_counts(normalize=True)
# Out:
# 0    0.638647
# 1    0.361353
# Name: class, dtype: float64

# %% [markdown]
# <font color = blue>Checking the distribution of the classes amount the original Broadcastify files.</font>

# %%
df0['class'] = df0.file_name.apply(lambda x: 0 if 'negative' in x else 1)

# %%
df0.head()
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  /home/ubuntu/audio_files/Neal Manahan - negati...
# 1           1  /home/ubuntu/audio_files/Neal Manahan - negati...
# 2           2  /home/ubuntu/audio_files/Neal Manahan - negati...
# 3           3  /home/ubuntu/audio_files/Neal Manahan - negati...
# 4           4  /home/ubuntu/audio_files/Neal Manahan - negati...
#
#   good_exception audio_recognition  class
# 0      Exception               NaN      0
# 1      Exception               NaN      0
# 2      Exception               NaN      0
# 3      Exception               NaN      0
# 4      Exception               NaN      0

# %%
df0.shape
# Out:
# (2898, 5)

# %%
df0[df0['good_exception'] == 'Good'].shape
# Out:
# (323, 5)

# %%
df0_text = df0[df0['good_exception'] == 'Good']
df0_text.head()
# Out:
#     Unnamed: 0                                          file_name  \
# 11          11  /home/ubuntu/audio_files/Neal Manahan - negati...
# 15          15  /home/ubuntu/audio_files/Neal Manahan - negati...
# 31          31  /home/ubuntu/audio_files/Neal Manahan - negati...
# 40          40  /home/ubuntu/audio_files/Neal Manahan - negati...
# 51          51  /home/ubuntu/audio_files/Neal Manahan - negati...
#
#    good_exception                                  audio_recognition  class
# 11           Good                                               3425      0
# 15           Good  phone number for Direct Control of Kendall Street      0
# 31           Good                                  20174 Perrysville      0
# 40           Good                                            Medical      0
# 51           Good                                p1191 Hyundai sedan      0

# %%
df0_text['class'].value_counts()
# Out:
# 1    197
# 0    126
# Name: class, dtype: int64

# %%
df0_text['class'].value_counts(normalize=True)
# Out:
# 1    0.609907
# 0    0.390093
# Name: class, dtype: float64

# %% [markdown]
# <font color = blue>Build tokens for the audio text.</font>

# %%
df_text.loc[11]['audio_recognition']
# Out:
# '3425'

# %%
df_text.head()
# Out:
#                                             file_name good_exception  \
# 11  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 15  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 31  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 40  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 51  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
#
#                                     audio_recognition  class
# 11                                               3425      0
# 15  phone number for Direct Control of Kendall Street      0
# 31                                  20174 Perrysville      0
# 40                                            Medical      0
# 51                                p1191 Hyundai sedan      0

# %%
df_text.reset_index()
# Out:
#       index                                          file_name good_exception  \
# 0        11  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 1        15  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 2        31  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 3        40  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 4        51  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 5        53  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 6        58  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 7        60  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 8        68  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 9        88  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 10       91  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 11       95  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 12       97  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 13      109  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 14      121  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 15      134  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 16      150  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 17      170  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 18      180  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 19      193  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 20      197  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 21      199  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 22      201  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 23      225  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 24      241  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 25      242  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 26      263  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 27      265  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 28      266  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 29      268  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 30      274  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 31      275  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 32      278  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 33      284  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 34      288  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 35      291  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 36      308  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 37      323  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 38      343  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 39      349  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 40      366  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 41      375  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 42      394  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 43      396  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 44      404  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 45      405  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 46      407  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 47      408  /home/ubuntu/audio_files/Rodolfo Flores - nega...           Good
# 48      414  /home/ubuntu/audio_files/Rodolfo Flores - nega...           Good
# 49      434  /home/ubuntu/audio_files/Rodolfo Flores - nega...           Good
# ...     ...                                                ...            ...
# 985    4294  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 986    4295  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 987    4298  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 988    4299  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 989    4300  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 990    4301  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 991    4302  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 992    4303  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 993    4304  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 994    4305  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 995    4306  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 996    4309  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 997    4311  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 998    4312  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 999    4313  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1000   4314  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1001   4315  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1002   4317  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1003   4318  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1004   4319  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1005   4320  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1006   4321  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1007   4322  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1008   4324  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1009   4325  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1010   4327  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1011   4328  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1012   4329  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1013   4330  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1014   4332  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1015   4333  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1016   4334  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1017   4336  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1018   4338  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1019   4339  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1020   4340  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1021   4342  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1022   4346  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1023   4347  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1024   4349  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1025   4350  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1026   4351  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1027   4352  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1028   4354  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1029   4356  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1030   4357  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1031   4363  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1032   4365  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1033   4366  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
# 1034   4367  /home/ubuntu/new_audios/Rodolfo Flores Mendez ...           Good
#
#                                       audio_recognition  class
# 0                                                  3425      0
# 1     phone number for Direct Control of Kendall Street      0
# 2                                     20174 Perrysville      0
# 3                                               Medical      0
# 4                                   p1191 Hyundai sedan      0
# 5                         Brownsville Belle Plaine 3311      0
# 6                                            California      0
# 7                                            California      0
# 8                                               details      0
# 9                                       since yesterday      0
# 10                       are there any units in Juniata      0
# 11                                                  324      0
# 12                                                   12      0
# 13                                                  322      0
# 14                       6th Avenue between Liberty and      0
# 15                                Street off of Weslaco      0
# 16                                                 3324      0
# 17                                             Siri 112      0
# 18                                                 3427      0
# 19                                                 3432      0
# 20                                            Odd Squad      0
# 21                                                 m156      0
# 22                                                  424      0
# 23                                                 3124      0
# 24       vehicle needs to be moved the red Nissan Versa      0
# 25                                                 2136      0
# 26                                     California 70466      0
# 27                                                  408      0
# 28                      Urban residents inaudible panic      0
# 29                            male white male breakdown      0
# 30                                       49047 to 49047      0
# 31                                                  108      0
# 32                             32 turn right 2013 Honda      0
# 33                                        all right now      0
# 34                                         644-769-6476      0
# 35                                           number one      0
# 36                                             negative      0
# 37                                       41901 Mariposa      0
# 38                                       turn off alarm      0
# 39             call Davis Market in Stockton California      0
# 40                                           California      0
# 41                                           100-300 F4      0
# 42                                          46th Street      0
# 43    30 years olds for Harrisonville tan jacket blu...      0
# 44                         Toyota Prius silver in color      0
# 45                                 California 665 Honda      0
# 46                                              neocity      0
# 47    it does not open 901 mine it was from a VoIP p...      0
# 48                                           Temple Run      0
# 49    for Juliet Romeo 297 2012 Nissan Rogue color r...      0
# ...                                                 ...    ...
# 985                                              Turn 4      1
# 986                          volume for the alarm alarm      1
# 987                               Closter 2288 forklift      1
# 988                                   cuz I got 130 KJR      1
# 989                                          handle 511      1
# 990   yes and just be advised this has no affiliatio...      1
# 991                                               Opera      1
# 992                                          Sai temple      1
# 993   Franklin 44140 West Lafayette Kiara Mason at t...      1
# 994                    5300 block of Cordelia softlayer      1
# 995                                    West 26th Street      1
# 996                           temperature is what it is      1
# 997                         restaurants on 207th Street      1
# 998              and 200 West Baltimore is THC Pharmacy      1
# 999                                             traffic      1
# 1000  assassin for an officer somebody is threatenin...      1
# 1001                                                 24      1
# 1002                                         picture of      1
# 1003                                               45 m      1
# 1004                                 weather show today      1
# 1005                                  300 North Charles      1
# 1006      Adderall use on 1 2 switch back to back today      1
# 1007                                  118 North Highway      1
# 1008                                      Weimar Street      1
# 1009                                       3 North Road      1
# 1010  320 York Road from 320 York Road for the armed...      1
# 1011                        welcome right back out back      1
# 1012                                  Crayola clear now      1
# 1013           I was up here you say that the day today      1
# 1014                                   16 North Holland      1
# 1015    I'm just inquiring if I had 2779 with dyspepsia      1
# 1016     Cloud over head to our old whose address again      1
# 1017                           05 everything okay there      1
# 1018                                       MP3 download      1
# 1019  I just want to sex living in Glen Oaks very li...      1
# 1020  reckless driver in the parking lot to New Orle...      1
# 1021                              Fairview and Garrison      1
# 1022                                           lingerie      1
# 1023  signal 30 at Moravia and Cold Springs also Har...      1
# 1024                                        Tim Hortons      1
# 1025                                         2016 worth      1
# 1026                                                 26      1
# 1027        down for anything change East Baltimore 409      1
# 1028                                       782-277-9779      1
# 1029          6011 cedonia unknown travel from anywhere      1
# 1030                                              Tupac      1
# 1031                           argument with girlfriend      1
# 1032                                          call Papa      1
# 1033  Piedmont North Haledon all secure no vehicle m...      1
# 1034                 and I was at Piedmont North Hilton      1
#
# [1035 rows x 5 columns]

# %%
df_reindexed_text = df_text.reset_index(drop=True)

# %%
df_reindexed_text.head()
# Out:
#                                            file_name good_exception  \
# 0  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 1  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 2  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 3  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
# 4  /home/ubuntu/audio_files/Neal Manahan - negati...           Good
#
#                                    audio_recognition  class
# 0                                               3425      0
# 1  phone number for Direct Control of Kendall Street      0
# 2                                  20174 Perrysville      0
# 3                                            Medical      0
# 4                                p1191 Hyundai sedan      0

# %%
df_reindexed_text.shape
# Out:
# (1035, 4)

# %%
text_list = []
for i in range(df_reindexed_text.shape[0]):
    text_list.append(df_reindexed_text.loc[i]['audio_recognition'])

# %%
len(text_list)
# Out:
# 1035

# %%
text = ''
for i in range(df_reindexed_text.shape[0]):
    text += df_reindexed_text.loc[i]['audio_recognition'] + ' '

# %%
len(text)
# Out:
# 27886

# %% [markdown]
# <font color = blue>First attempt at creating tokens from the text.</font>

# %%
tokenizer = RegexpTokenizer(r'\w+')

# spam_tokens = tokenizer.tokenize(spam.lower())
text_tokens = tokenizer.tokenize(text.lower())

# %%
len(text_tokens)
# Out:
# 5037

# %%
text_tokens
# Out:
# ['3425',
#  'phone',
#  'number',
#  'for',
#  'direct',
#  'control',
#  'of',
#  'kendall',
#  'street',
#  '20174',
#  'perrysville',
#  'medical',
#  'p1191',
#  'hyundai',
#  'sedan',
#  'brownsville',
#  'belle',
#  'plaine',
#  '3311',
#  'california',
#  'california',
#  'details',
#  'since',
#  'yesterday',
#  'are',
#  'there',
#  'any',
#  'units',
#  'in',
#  'juniata',
#  '324',
#  '12',
#  '322',
#  '6th',
#  'avenue',
#  'between',
#  'liberty',
#  'and',
#  'street',
#  'off',
#  'of',
#  'weslaco',
#  '3324',
#  'siri',
#  '112',
#  '3427',
#  '3432',
#  'odd',
#  'squad',
#  'm156',
#  '424',
#  '3124',
#  'vehicle',
#  'needs',
#  'to',
#  'be',
#  'moved',
#  'the',
#  'red',
#  'nissan',
#  'versa',
#  '2136',
#  'california',
#  '70466',
#  '408',
#  'urban',
#  'residents',
#  'inaudible',
#  'panic',
#  'male',
#  'white',
#  'male',
#  'breakdown',
#  '49047',
#  'to',
#  '49047',
#  '108',
#  '32',
#  'turn',
#  'right',
#  '2013',
#  'honda',
#  'all',
#  'right',
#  'now',
#  '644',
#  '769',
#  '6476',
#  'number',
#  'one',
#  'negative',
#  '41901',
#  'mariposa',
#  'turn',
#  'off',
#  'alarm',
#  'call',
#  'davis',
#  'market',
#  'in',
#  'stockton',
#  'california',
#  'california',
#  '100',
#  '300',
#  'f4',
#  '46th',
#  'street',
#  '30',
#  'years',
#  'olds',
#  'for',
#  'harrisonville',
#  'tan',
#  'jacket',
#  'blue',
#  'jeans',
#  'toyota',
#  'prius',
#  'silver',
#  'in',
#  'color',
#  'california',
#  '665',
#  'honda',
#  'neocity',
#  'it',
#  'does',
#  'not',
#  'open',
#  '901',
#  'mine',
#  'it',
#  'was',
#  'from',
#  'a',
#  'voip',
#  'phone',
#  'named',
#  'for',
#  'temple',
#  'run',
#  'for',
#  'juliet',
#  'romeo',
#  '297',
#  '2012',
#  'nissan',
#  'rogue',
#  'color',
#  'red',
#  'it',
#  'comes',
#  'out',
#  'of',
#  'everett',
#  'the',
#  'vehicle',
#  'is',
#  'active',
#  'last',
#  'name',
#  'in',
#  'washington',
#  'and',
#  'malden',
#  'street',
#  'erratic',
#  'driver',
#  'again',
#  'for',
#  'juliet',
#  'romeo',
#  'driver',
#  'taking',
#  'a',
#  'right',
#  'onto',
#  'marvin',
#  'street',
#  'off',
#  'of',
#  'washington',
#  'organic',
#  'coffee',
#  'control',
#  'to',
#  'repair',
#  'in',
#  'callahan',
#  'could',
#  'you',
#  'give',
#  'me',
#  'a',
#  'call',
#  'today',
#  'colossus',
#  'honda',
#  'parts',
#  'colton',
#  'underwood',
#  'broadway',
#  'street',
#  'and',
#  'f',
#  'street',
#  '916',
#  '3916',
#  '08390',
#  '35',
#  'hampton',
#  'courts',
#  'tv',
#  'going',
#  'on',
#  'what',
#  'time',
#  'is',
#  'it',
#  '49ers',
#  'call',
#  'david',
#  'burger',
#  'king',
#  'on',
#  'howard',
#  'thailand',
#  '000',
#  '71559',
#  'control',
#  '703',
#  '301',
#  '1300',
#  'country',
#  'show',
#  'me',
#  'a',
#  'flight',
#  'now',
#  'teamworks',
#  'party',
#  '365',
#  'nv20',
#  'apartments',
#  'control',
#  '3549',
#  '41',
#  'how',
#  'to',
#  'make',
#  'a',
#  'sprinkler',
#  'gina',
#  'philips',
#  'paragon',
#  '12',
#  'tracfone',
#  '1st',
#  'peter',
#  'hma',
#  'hma',
#  'we',
#  'haven',
#  't',
#  'called',
#  'right',
#  'now',
#  'friend',
#  'from',
#  'school',
#  'victor',
#  'neri',
#  'david',
#  '360',
#  'barney',
#  'engineering',
#  'firm',
#  'i',
#  'll',
#  'get',
#  'you',
#  'an',
#  'address',
#  'when',
#  'i',
#  'get',
#  'there',
#  'parking',
#  'route',
#  '439',
#  'robber',
#  '1251',
#  'east',
#  'nelson',
#  'avenue',
#  'district',
#  '2126',
#  'herschel',
#  'walker',
#  'happy',
#  'birthday',
#  'fernando',
#  'kinkos',
#  '9',
#  'pill',
#  '349',
#  'charlie',
#  'puth',
#  '45',
#  'centennial',
#  'and',
#  'losee',
#  'centennial',
#  'tradutor',
#  '1531',
#  'patrol',
#  'unexpected',
#  'turn',
#  'on',
#  'flashlight',
#  'wells',
#  'fargo',
#  '4th',
#  'and',
#  'q',
#  'europa',
#  'report',
#  'earlier',
#  'vancouver',
#  'david',
#  '02',
#  'adam',
#  'gilby',
#  '12279',
#  'california',
#  'dl',
#  'baker',
#  '514',
#  '2791',
#  'aaron',
#  'baker',
#  'chaos',
#  'controls',
#  'pham',
#  '1901',
#  'what',
#  'sound',
#  'is',
#  'that',
#  'you',
#  'turn',
#  'with',
#  'a',
#  'rc',
#  'car',
#  '67437',
#  'sunrise',
#  'mobile',
#  'home',
#  'park',
#  'channel',
#  '7',
#  'rescue',
#  '21',
#  'year',
#  'old',
#  'acting',
#  'violent',
#  'community',
#  'north',
#  'entrance',
#  'coffee',
#  'harrah',
#  's',
#  'laughlin',
#  'attorneys',
#  'in',
#  'whitehall',
#  'equipment',
#  'with',
#  'security',
#  'home',
#  'home',
#  'call',
#  'connor',
#  'call',
#  'connor',
#  '83',
#  '83',
#  'sfo',
#  'airport',
#  'airplane',
#  'crash',
#  'blackheads',
#  '4347',
#  'tyrell',
#  'on',
#  'a',
#  'wire',
#  'rack',
#  'in',
#  'westerville',
#  'something',
#  'exploded',
#  'are',
#  'in',
#  '1',
#  '2',
#  'hour',
#  'butter',
#  'down',
#  'can',
#  'i',
#  'send',
#  'anybody',
#  'having',
#  'an',
#  'snl',
#  'corner',
#  'of',
#  'merle',
#  'haggard',
#  'old',
#  'daycare',
#  'some',
#  'shorts',
#  'call',
#  'foreclosure',
#  'county',
#  '4425',
#  'are',
#  'you',
#  'sure',
#  'tori',
#  'brixx',
#  'of',
#  'the',
#  'building',
#  'evidence',
#  'my',
#  'location',
#  '39',
#  '44',
#  'i',
#  'only',
#  'want',
#  'to',
#  'hear',
#  'from',
#  'the',
#  '90s',
#  'for',
#  'i',
#  'don',
#  't',
#  'want',
#  'to',
#  'hear',
#  'from',
#  'that',
#  'supervisor',
#  'ringworld',
#  'quiz',
#  'street',
#  'kosovo',
#  'is',
#  'it',
#  'going',
#  'today',
#  'going',
#  '755',
#  'boylston',
#  'library',
#  'call',
#  'cara',
#  'copy',
#  'supervisor',
#  'we',
#  'will',
#  'call',
#  'right',
#  'away',
#  'uok',
#  'we',
#  're',
#  'on',
#  'our',
#  'way',
#  'back',
#  'to',
#  'ruin',
#  'it',
#  'okay',
#  'see',
#  'you',
#  'there',
#  'might',
#  'be',
#  'possible',
#  'additional',
#  'devices',
#  'once',
#  'again',
#  'all',
#  'of',
#  'the',
#  'devices',
#  'in',
#  'the',
#  'area',
#  'are',
#  'underweight',
#  'are',
#  'there',
#  'on',
#  'the',
#  'way',
#  'watch',
#  'traffic',
#  'again',
#  'what',
#  'was',
#  'the',
#  'location',
#  'of',
#  'that',
#  'backpack',
#  'that',
#  'last',
#  'backpack',
#  'i',
#  'need',
#  'a',
#  'location',
#  'columbus',
#  'county',
#  'warrants',
#  'green',
#  'road',
#  'ring',
#  'road',
#  'over',
#  'alpha',
#  'one',
#  'fb',
#  'inc',
#  'wake',
#  'up',
#  'with',
#  'you',
#  'we',
#  're',
#  'going',
#  'to',
#  'right',
#  'away',
#  'sir',
#  'copyright',
#  'boylston',
#  'oh',
#  'traffic',
#  'call',
#  '11',
#  'xbox',
#  'one',
#  'empire',
#  'rainbow',
#  'at',
#  'royalton',
#  'royalton',
#  'medical',
#  'pavilion',
#  'all',
#  'company',
#  'george',
#  'closet',
#  '1702',
#  '43017',
#  'quadracarn',
#  'bywater',
#  'a',
#  'company',
#  '4222',
#  'okay',
#  '21',
#  '21',
#  '25',
#  '40',
#  'turn',
#  'off',
#  'the',
#  '106',
#  'delta',
#  'one',
#  '1303',
#  'popeyes',
#  '2141',
#  'public',
#  'library',
#  'library',
#  'fireball',
#  'vocabulary',
#  'bmf',
#  'boylston',
#  'carmen',
#  'buttercup',
#  'you',
#  'to',
#  'come',
#  'up',
#  'with',
#  'the',
#  'opposite',
#  'way',
#  'mediacom',
#  '41182',
#  'laguna',
#  'clay',
#  'county',
#  'library',
#  '1',
#  'jfk',
#  'drive',
#  '41',
#  '1821',
#  'jfk',
#  'drive',
#  'fortunately',
#  'okay',
#  'ko',
#  'boston',
#  'fire',
#  'department',
#  'ems',
#  'call',
#  '110',
#  '513',
#  '2200',
#  'open',
#  'whatsapp',
#  'delray',
#  'marketplace',
#  '21',
#  'firethorn',
#  'call',
#  'country',
#  's',
#  'on',
#  'train',
#  'monica',
#  'car',
#  'payment',
#  'used',
#  'car',
#  'call',
#  'net10',
#  '105',
#  'with',
#  'cpr',
#  'at',
#  'price',
#  'to',
#  'airport',
#  'road',
#  'fairfield',
#  'inn',
#  'express',
#  'target',
#  'boston',
#  'police',
#  'report',
#  'a',
#  'possible',
#  'secondary',
#  'device',
#  'call',
#  'joey',
#  'getting',
#  'boylston',
#  'street',
#  'in',
#  'harford',
#  'street',
#  'phillipsburg',
#  'ticket',
#  'packages',
#  'okay',
#  'place',
#  'an',
#  'order',
#  'another',
#  'one',
#  'right',
#  'now',
#  'call',
#  'kali',
#  'camaro',
#  'r1',
#  'report',
#  'drive',
#  'i',
#  'want',
#  'to',
#  'keep',
#  'oil',
#  'sinclair',
#  'between',
#  'editor',
#  'and',
#  'fairfield',
#  'hillside',
#  'okay',
#  'ok',
#  'google',
#  'device',
#  'boylston',
#  'street',
#  'by',
#  'the',
#  'library',
#  'operator',
#  'direct',
#  'you',
#  'want',
#  'what',
#  'you',
#  'want',
#  'answering',
#  'right',
#  'now',
#  '44531',
#  'pill',
#  'call',
#  'connor',
#  'pinecroft',
#  '793',
#  'boylston',
#  'street',
#  'dental',
#  'cairo',
#  'madeline',
#  'state',
#  'golfer',
#  '12th',
#  'and',
#  'diamond',
#  'okay',
#  'if',
#  'you',
#  'want',
#  'to',
#  'give',
#  'you',
#  'a',
#  'rundown',
#  'set',
#  'alarm',
#  'at',
#  '1',
#  'alarm',
#  'at',
#  '1',
#  'weather',
#  'ohio',
#  'culinary',
#  'electrical',
#  'papaya',
#  'fruit',
#  'call',
#  'target',
#  'near',
#  'palomar',
#  'college',
#  'map',
#  'negative',
#  'at',
#  '1',
#  'tell',
#  'my',
#  'wife',
#  'to',
#  'call',
#  '7120',
#  '20th',
#  'avenue',
#  'call',
#  '404',
#  '281',
#  '0110',
#  'where',
#  'can',
#  'i',
#  'go',
#  'for',
#  'free',
#  'in',
#  'atlanta',
#  'for',
#  '715',
#  'atlanta',
#  'deli',
#  'ohio',
#  'lottery',
#  'call',
#  'on',
#  'the',
#  'greenhouse',
#  'call',
#  'kathy',
#  'hoffman',
#  'can',
#  'you',
#  'take',
#  'a',
#  'retard',
#  '793',
#  'boylston',
#  '793',
#  'boylston',
#  'st',
#  'water',
#  'company',
#  'boylston',
#  'and',
#  'dartmouth',
#  'and',
#  'i',
#  'll',
#  'send',
#  'an',
#  'additional',
#  'engines',
#  'that',
#  'the',
#  'alleyway',
#  'xl44',
#  'oh',
#  'so',
#  'i',
#  'can',
#  'come',
#  'you',
#  'off',
#  'a',
#  'cliff',
#  'diver',
#  'tree',
#  'haul',
#  'treatment',
#  'club',
#  'port',
#  'royal',
#  'tn',
#  'topix',
#  'intercourse',
#  '22',
#  'is',
#  'also',
#  'at',
#  'the',
#  'party',
#  'are',
#  'opposite',
#  'corner',
#  'of',
#  'boylston',
#  'and',
#  'exeter',
#  'call',
#  'cordy',
#  'glenn',
#  'define',
#  'lapidary',
#  'kentucky',
#  'bobby',
#  'capo',
#  'st',
#  'james',
#  'avery',
#  'just',
#  'got',
#  'to',
#  'get',
#  'over',
#  'to',
#  'boil',
#  'for',
#  '3',
#  'maybe',
#  'to',
#  'boylston',
#  'and',
#  'come',
#  'up',
#  'baby',
#  'clouded',
#  'to',
#  'add',
#  'weekend',
#  'georgia',
#  'boylston',
#  'right',
#  'now',
#  'all',
#  'the',
#  'way',
#  'up',
#  'we',
#  'have',
#  'left',
#  'until',
#  '11',
#  '17',
#  'carlisle',
#  'street',
#  'evaporada',
#  'africa',
#  'map',
#  'call',
#  'divya',
#  'mandarin',
#  '3133',
#  'fairfield',
#  'inn',
#  'newburyport',
#  'otelco',
#  'volume',
#  'at',
#  '45',
#  'carpal',
#  'how',
#  'are',
#  'you',
#  'how',
#  'you',
#  'make',
#  'out',
#  'with',
#  'your',
#  'assignment',
#  'call',
#  'robert',
#  'gray',
#  'pictures',
#  'of',
#  'bella',
#  'vista',
#  'one',
#  'call',
#  'ilana',
#  '15',
#  'what',
#  'is',
#  'the',
#  'location',
#  'of',
#  'royal',
#  'bigmans',
#  'pizza',
#  'call',
#  'congress',
#  'located',
#  'adjacent',
#  'to',
#  'the',
#  'copley',
#  'square',
#  'library',
#  'today',
#  'the',
#  'top',
#  'of',
#  'the',
#  'boil',
#  '45',
#  '100',
#  'app',
#  'map',
#  'route',
#  'seattle',
#  'okay',
#  'what',
#  's',
#  'the',
#  'weather',
#  'look',
#  'like',
#  'on',
#  'my',
#  'lap',
#  'right',
#  'up',
#  'the',
#  'stage',
#  'at',
#  'the',
#  'lapin',
#  'boylston',
#  'street',
#  ...]

# %%
text
# Out:
# "3425 phone number for Direct Control of Kendall Street 20174 Perrysville Medical p1191 Hyundai sedan Brownsville Belle Plaine 3311 California California details since yesterday are there any units in Juniata 324 12 322 6th Avenue between Liberty and Street off of Weslaco 3324 Siri 112 3427 3432 Odd Squad m156 424 3124 vehicle needs to be moved the red Nissan Versa 2136 California 70466 408 Urban residents inaudible panic male white male breakdown 49047 to 49047 108 32 turn right 2013 Honda all right now 644-769-6476 number one negative 41901 Mariposa turn off alarm call Davis Market in Stockton California California 100-300 F4 46th Street 30 years olds for Harrisonville tan jacket blue jeans Toyota Prius silver in color California 665 Honda neocity it does not open 901 mine it was from a VoIP phone named for Temple Run for Juliet Romeo 297 2012 Nissan Rogue color red it comes out of Everett the vehicle is active last name in Washington and Malden Street erratic driver again for Juliet Romeo driver taking a right onto Marvin Street off of Washington organic coffee control to repair in Callahan could you give me a call today Colossus Honda parts Colton Underwood Broadway Street and F Street 916-3916 08390 35 Hampton Courts TV going on what time is it 49ers call David Burger King on Howard Thailand 000 71559 control 703-301-1300 country show me a flight now Teamworks party 365 nv20 Apartments control 3549 41 how to make a sprinkler Gina Philips Paragon 12 TracFone 1st Peter hma-hma we haven't called right now. friend from school Victor Neri David 360 Barney engineering firm I'll get you an address when I get there parking route 439 robber 1251 East Nelson Avenue District 2126 Herschel Walker happy birthday Fernando Kinkos 9 pill 349 Charlie puth 45 Centennial and Losee Centennial tradutor 1531 Patrol unexpected turn on flashlight Wells Fargo 4th and Q Europa Report earlier Vancouver David 02 Adam gilby 12279 California DL Baker 514-2791 Aaron Baker chaos controls Pham 1901 what sound is that you turn with a RC car 67437 Sunrise Mobile Home Park Channel 7 rescue 21 year old acting violent Community north entrance coffee Harrah's Laughlin attorneys in Whitehall equipment with security home home call Connor call Connor 83 83 SFO airport airplane crash blackheads 4347 Tyrell on a wire rack in Westerville something exploded are in 1/2 hour butter down can I send anybody having an SNL corner of Merle Haggard old daycare some shorts call foreclosure County 4425 are you sure Tori Brixx of the building evidence my location 39 + 44 I only want to hear from the 90s for I don't want to hear from that supervisor Ringworld quiz Street Kosovo is it going today going 755 Boylston Library call Cara copy. supervisor we will call right away uok we're on our way back to ruin it. Okay see you there might be possible additional devices once again all of the devices in the area are underweight are there on the way watch traffic again what was the location of that backpack that last backpack I need a location Columbus County warrants Green Road Ring Road over Alpha One FB Inc wake up with you we're going to right away sir copyright Boylston oh traffic call 11 Xbox One Empire rainbow at Royalton Royalton Medical Pavilion all company George closet 1702 43017 quadracarn Bywater a company 4222 okay 21 21 25 40 turn off the 106 Delta one 1303 Popeyes 2141 public library library Fireball vocabulary BMF Boylston, Carmen Buttercup you to come up with the opposite way Mediacom 41182 Laguna Clay County Library 1 JFK Drive 41 1821 JFK Drive fortunately. okay KO Boston Fire Department EMS call 110-513-2200 open WhatsApp Delray Marketplace 21 Firethorn call Country's on train Monica car payment used car call Net10 105 with CPR at price to Airport Road Fairfield Inn Express Target Boston police report a possible secondary device call Joey getting Boylston Street in Harford Street Phillipsburg ticket packages okay place an order another one right now call Kali Camaro ...

# %%
# This is the list of text.

text_list
# Out:
# ['3425',
#  'phone number for Direct Control of Kendall Street',
#  '20174 Perrysville',
#  'Medical',
#  'p1191 Hyundai sedan',
#  'Brownsville Belle Plaine 3311',
#  'California',
#  'California',
#  'details',
#  'since yesterday',
#  'are there any units in Juniata',
#  '324',
#  '12',
#  '322',
#  '6th Avenue between Liberty and',
#  'Street off of Weslaco',
#  '3324',
#  'Siri 112',
#  '3427',
#  '3432',
#  'Odd Squad',
#  'm156',
#  '424',
#  '3124',
#  'vehicle needs to be moved the red Nissan Versa',
#  '2136',
#  'California 70466',
#  '408',
#  'Urban residents inaudible panic',
#  'male white male breakdown',
#  '49047 to 49047',
#  '108',
#  '32 turn right 2013 Honda',
#  'all right now',
#  '644-769-6476',
#  'number one',
#  'negative',
#  '41901 Mariposa',
#  'turn off alarm',
#  'call Davis Market in Stockton California',
#  'California',
#  '100-300 F4',
#  '46th Street',
#  '30 years olds for Harrisonville tan jacket blue jeans',
#  'Toyota Prius silver in color',
#  'California 665 Honda',
#  'neocity',
#  'it does not open 901 mine it was from a VoIP phone named for',
#  'Temple Run',
#  'for Juliet Romeo 297 2012 Nissan Rogue color red it comes out of Everett',
#  'the vehicle is active last name in Washington and Malden Street erratic driver again for Juliet Romeo driver taking a right onto Marvin Street off of Washington',
#  'organic coffee',
#  'control to repair in Callahan',
#  'could you give me a call today',
#  'Colossus',
#  'Honda parts',
#  'Colton Underwood',
#  'Broadway Street and F Street',
#  '916-3916',
#  '08390',
#  '35',
#  'Hampton Courts',
#  'TV going on',
#  'what time is it',
#  '49ers',
#  'call David',
#  'Burger King on Howard',
#  'Thailand',
#  '000',
#  '71559',
#  'control',
#  '703-301-1300',
#  'country',
#  'show me a flight now',
#  'Teamworks party',
#  '365 nv20',
#  'Apartments',
#  'control 3549',
#  '41',
#  'how to make a sprinkler',
#  'Gina Philips',
#  'Paragon 12',
#  'TracFone',
#  '1st Peter',
#  'hma-hma',
#  "we haven't called right now.",
#  'friend from school',
#  'Victor Neri David 360',
#  'Barney',
#  'engineering firm',
#  "I'll get you an address when I get there",
#  'parking route 439 robber',
#  '1251 East Nelson Avenue District 2126',
#  'Herschel Walker',
#  'happy birthday',
#  'Fernando Kinkos 9',
#  'pill 349',
#  'Charlie puth',
#  '45',
#  'Centennial and Losee Centennial',
#  'tradutor',
#  '1531 Patrol',
#  'unexpected',
#  'turn on flashlight',
#  'Wells Fargo 4th and Q',
#  'Europa Report',
#  'earlier',
#  'Vancouver David 02',
#  'Adam gilby 12279 California DL Baker 514-2791',
#  'Aaron Baker',
#  'chaos',
#  'controls Pham 1901',
#  'what sound is that you turn with a RC car 67437',
#  'Sunrise Mobile Home Park',
#  'Channel 7 rescue 21 year old acting violent',
#  'Community north entrance',
#  'coffee',
#  "Harrah's Laughlin",
#  'attorneys in Whitehall',
#  'equipment with security',
#  'home',
#  'home',
#  'call Connor',
#  'call Connor',
#  '83',
#  '83',
#  'SFO airport airplane crash',
#  'blackheads',
#  '4347',
#  'Tyrell on a wire rack in Westerville something exploded are in 1/2 hour butter down can I send anybody having an SNL',
#  'corner of',
#  'Merle Haggard',
#  'old daycare some shorts',
#  'call foreclosure County',
#  '4425',
#  'are you sure',
#  'Tori Brixx',
#  'of the building',
#  'evidence',
#  'my location',
#  '39 + 44',
#  "I only want to hear from the 90s for I don't want to hear from that supervisor",
#  'Ringworld quiz',
#  'Street',
#  'Kosovo',
#  'is it going today going',
#  '755 Boylston',
#  'Library',
#  'call Cara copy.',
#  'supervisor',
#  'we will call right away',
#  'uok',
#  "we're on our way back to ruin it. Okay see you there",
#  'might be possible additional devices once again all of the devices in the area',
#  'are underweight are there on the way',
#  'watch traffic again',
#  'what was the location of that backpack that last backpack I need a location',
#  'Columbus County warrants',
#  'Green Road',
#  'Ring Road over Alpha One',
#  'FB Inc',
#  'wake up with you',
#  "we're going to",
#  'right away sir',
#  'copyright',
#  'Boylston',
#  'oh traffic',
#  'call',
#  '11',
#  'Xbox One',
#  'Empire',
#  'rainbow at Royalton Royalton',
#  'Medical Pavilion all company George closet',
#  '1702',
#  '43017',
#  'quadracarn',
#  'Bywater',
#  'a company 4222 okay',
#  '21 21 25 40',
#  'turn off the 106 Delta one 1303',
#  'Popeyes',
#  '2141',
#  'public library library',
#  'Fireball vocabulary BMF',
#  'Boylston, Carmen Buttercup you to come up with the opposite way',
#  'Mediacom 41182 Laguna Clay County Library 1 JFK Drive 41 1821 JFK Drive',
#  'fortunately.',
#  'okay KO Boston Fire Department EMS',
#  'call 110-513-2200',
#  'open WhatsApp',
#  'Delray Marketplace',
#  '21 Firethorn',
#  "call Country's on train",
#  'Monica',
#  'car payment used car',
#  'call Net10 105 with CPR at price to Airport Road',
#  'Fairfield Inn Express',
#  'Target',
#  'Boston police report a possible secondary device',
#  'call Joey getting Boylston Street in Harford Street Phillipsburg ticket packages',
#  'okay',
#  'place an order another one right now',
#  'call Kali Camaro R1 report Drive I want to keep oil Sinclair between editor and Fairfield',
#  'Hillside okay',
#  'OK Google device',
#  'Boylston Street by the library',
#  'operator direct you want what you want answering right now',
#  '44531 pill',
#  'call Connor Pinecroft',
#  '793 Boylston Street Dental Cairo',
#  'Madeline State golfer 12th and diamond',
#  'okay if you want to give you a rundown',
#  'set alarm at 1 alarm at 1',
#  'weather Ohio culinary electrical',
#  'papaya fruit',
#  'call Target near Palomar College map',
#  'negative at 1 tell my wife to call',
#  '7120 20th Avenue',
#  'call 404-281-0110',
#  'where can I go for free in Atlanta for',
#  '715 Atlanta Deli',
#  'Ohio Lottery',
#  'call on the greenhouse, call Kathy Hoffman',
#  'can you take a retard 793 Boylston 793 Boylston St',
#  "water company Boylston and Dartmouth and I'll send an additional engines that the alleyway xl44 oh",
#  'so I can come you off a cliff diver Tree haul treatment Club, Port Royal TN Topix',
#  'intercourse',
#  '22 is also at the party are opposite corner of Boylston and Exeter',
#  'call Cordy Glenn',
#  'Define lapidary Kentucky',
#  'Bobby Capo',
#  'St James Avery just got to get over to boil for 3 maybe to Boylston',
#  'and come up baby clouded to add weekend Georgia Boylston right now all the way up',
#  'we have left until 11:17',
#  'Carlisle Street evaporada',
#  'africa map',
#  'call Divya Mandarin 3133',
#  'Fairfield Inn Newburyport otelco',
#  'volume at 45%',
#  'carpal how are you how you make out with your assignment',
#  'call Robert gray pictures of Bella Vista one',
#  'call Ilana 15 what is the location of Royal bigmans pizza',
#  'call Congress located adjacent to the Copley Square library today the top of the boil',
#  '45 / 100',
#  'app map route Seattle',
#  "okay what's the weather look like on my lap right up the stage at the Lapin Boylston Street",
#  'broadcast we got an email Drive',
#  'Sofia Coppola call you at 2',
#  'California Angels I can see you',
#  'do I have anything available response to the JFK Library',
#  'take me to the airport by 11 to go to the JFK Library',
#  'set alarm stage at Boylston and Mass Ave',
#  'Saints Row Drive',
#  'call the command post at the waxing',
#  'do you want me to come up',
#  'okay what time it is when did the 793',
#  'OK Google message Alyssa Hamilton 14 and ladder company one with you',
#  'where do I go to 2933 for',
#  'Royalton Royalton call portable carport',
#  '1144 / 1746',
#  'play 17 call Pilar 24',
#  'Charlie wants to the Watertown',
#  'Pappadeaux',
#  'Reserve at Walnut Creek',
#  'budget way',
#  'Watertown talk to North Metro to White House',
#  'Rio Bravo to the Yankees',
#  'Walmart',
#  '953 go ahead',
#  'play on the radio',
#  'spell talk',
#  'call Advance Auto in Crowley area',
#  'send.',
#  '67 Franklin',
#  'walnut walnut',
#  'okay can you make your way out tomorrow to take this over in everybody else back off',
#  'OverWatch from the Foreside house teleport',
#  'I need you to do whatever you can to get',
#  '93803 two guys watch open mic',
#  'play officer Eddie police officer in the rear of the garage behind the White House you need to evacuate that area any officer in the garage',
#  'location okay 903',
#  'okay',
#  'can I get confirmation that was up for fortune on the other side of the phone',
#  'backyard you need to remove immediately',
#  'the two officers in the line of fire',
#  'weapon Squad in the area',
#  'certified credit',
#  'standby',
#  'from the corner of the house',
#  'make a radio silence on a boat',
#  'information from the aircraft',
#  'oh 3 or is that the other agencies',
#  'Half & Half Full half full',
#  'abc11',
#  'backing up into driveway on walnut walnut',
#  'Cota Cota',
#  'refraction',
#  'on the phone I want you to come',
#  '33503',
#  'another option try to get their work',
#  '903-319-3230',
#  'Drake net worth',
#  'okay coffee dial free laptops on Dell laptop',
#  'Call wifey',
#  'control',
#  'set alarm for 5',
#  'Jovani off the 101',
#  "watch your Mike's watch am I to get an open mic watch a mic",
#  'open mike watching Mike',
#  '14 form',
#  '1202 Franklin',
#  'Play Day place off the Franklin Walnut vehicles',
#  'petty officer',
#  'jaccob',
#  'Geico',
#  'FBI HRT',
#  'retro shorts',
#  'Ricart Ford',
#  'Toyota 903',
#  'Watertown',
#  'Petro Maldonado regroup Ativan',
#  'Rachel Jackson',
#  'where can I buy Cartoon Network SEC texture',
#  'the district maybe we can get a hold of them Wiley Avenue',
#  'West Virginia',
#  'individual',
#  'Southbound on Warwick',
#  '2021',
#  'stop',
#  'heart',
#  'art',
#  'shut off',
#  'Prosecco',
#  '1032 * 1205',
#  'RockAuto',
#  'California',
#  'information',
#  'make a note',
#  '1231 come in and pick up',
#  'red or maroon',
#  '23isBack',
#  "what's the number to",
#  '1664 South Blue Island',
#  '1231',
#  'midnight',
#  '1163',
#  'good morning',
#  '712 West Diversey Apartments',
#  'videos',
#  'first one I gave you',
#  'adorable',
#  'call 71',
#  "what's going on at 679 North Peoria",
#  'call Ice mobile',
#  '1243 30th Street South',
#  'Android on Mac',
#  'call Brandt Pike',
#  'April 11th',
#  'set timer for 1 round 651',
#  'track bar',
#  'set timer for 7:28',
#  'character Warehouse service 3937 Parkcrest Street 39th and Lawrence Mass 116-117 to 8048 us-51',
#  '4 + 2 + 10 + 5',
#  'several products recorder',
#  '29',
#  '14 run the same truck work Anchorman',
#  '29 a fire alarm',
#  'American Water',
#  'one liners',
#  '1',
#  '23',
#  'magnesium',
#  'hours of magnesium in the basement',
#  '45804',
#  "we've located The Patriot",
#  'funny',
#  "the basement wasn't burning man set time",
#  'why does he ever put his magnesium is not on fire this time',
#  'Eastside',
#  '3213 Harvard St',
#  '804 daleview',
#  'Halo 4',
#  'Aquarius over here',
#  'Airport',
#  '4626 and service',
#  "you're unable to find a guitar",
#  '87 zombie themed parlor',
#  '19 * 39',
#  'recorder',
#  'what corner of the building',
#  '21 and Hayes',
#  'phone calling AT&T 2914 732 letter v',
#  '1041',
#  'residency',
#  'third line',
#  'Network',
#  'ameritree',
#  'ringer service',
#  "smoke issuing from the vent has the much worse and now we're getting Smoke on the other side of that partition wall down the middle",
#  'fishing Morris County',
#  '13',
#  'pretty one trailer',
#  'real progress report and time is 11:02',
#  'inside the second garage door from this house there is a propane Cajun there was some units on the first floor',
#  '3937 39th and Lawrence Mass 116 1931 29th and Park',
#  "Carter's",
#  '39th and Park',
#  'coming out',
#  '1110 highlands Plaza Drive East',
#  'Mazda CX-7',
#  'Airport',
#  'call companies on 39th and Sheridan Park evacuation building',
#  'before you can return of service',
#  'FirstEnergy evacuated the building as primary',
#  'building 3937 Park Street at 39th and Lawrence 116 + 9.2 + 8',
#  'cross the road',
#  '804-802-0802',
#  'porterhouse',
#  'yes hopefully.',
#  'Whataburger',
#  'alarm',
#  '32 driver receive the message',
#  'accounted for ovens automatically accounted for all members of 14 are accounted for',
#  'members of Ricker exterior',
#  'immediate Moore',
#  'freeway 54 49.5',
#  'Chattanooga',
#  'in front of it',
#  '885 radio for information management is making the decision to put everyone out of the',
#  'but',
#  'Dogwood Court, Vermont',
#  '58050 Beechtree Court',
#  'go ahead',
#  "properly clean for everybody's concern",
#  'young James Brown',
#  "I'm in town on 8585",
#  'your band your department fan',
#  'notify me if that changes the name, then we will switch over to open allergy pills on one primary one',
#  '88888 John Cena',
#  "we're trying to get that radio",
#  'call from the earth Trading Company',
#  'Forever 21 in Yankee Candle',
#  'store with their Gates until I',
#  "the next day they want but I didn't see their call",
#  'okay thank you',
#  'bright white creme lightener over the mall parking lot going on at the very helpful',
#  '185 Adams',
#  '300 cars near 835 845',
#  "JCPenney's and I'm walking down",
#  '39243 Taco Bell',
#  'Tree of Life',
#  'Paw Patrol Hanover and Plaza',
#  'I want a trout from',
#  '26th Avenue',
#  '39',
#  'Coleman',
#  '39th Street parking lot',
#  'where are responding today',
#  'Cinemark the media area and grout park I think in direct all media route Park on bowling Boulevard',
#  'May 31st',
#  'chukar crafter Guitar Center',
#  'Marriott',
#  'call city of Bend westbound towards of Shelbyville Road Plaza in',
#  'Joann Fabrics',
#  'phone calls work Grant Park',
#  'just outside of arm Before Time',
#  '41 Whitney Point',
#  'auston Matthews Baytown PD radio and call this phone be the middle section still have the area next door just to the left of the mall from Taco Bell straightener break correct correction',
#  'call Western Shelbyville Road Plaza in anything still west of that everybody will be responsible for their phones great across 67th North at Sovereign group',
#  'just make sure they are they follow around group winner',
#  'number 43 car',
#  "groups trying to get back in the mall where to Victoria's Secret in our house area",
#  'call Page 39 what about a bus stop Cross Road',
#  'another',
#  'here is about a group of six or seven hundred LA Fitness time',
#  '21 grapefruit',
#  'Taco Bell',
#  'Chick-fil-A',
#  'pretty clear backyard Bayou Nepal',
#  'her son was outside on the porch with the guys three people were walking down the street towards Butler a car',
#  'operation',
#  'text animation with chemical eggs',
#  '42 units on south field support the return to 4th and accept the portion and secure the four Baptist time',
#  'black Lillies 50th St',
#  'turn down on the 5th Circle',
#  '4th Avenue and Oakland Avenue',
#  'call Battlefield 4 gas appointment tactical spacing',
#  'National Guard deers',
#  'has ever seen in my life and and and',
#  'Porsche watch shooting',
#  'company beginning now',
#  'important',
#  'f99 thank you',
#  'University',
#  'directions to store',
#  'Animal Control',
#  'EMS',
#  '25',
#  '413 Arthur',
#  'the weather',
#  'Verizon benefind',
#  'all together',
#  'traffic',
#  'contacted everyone so yes',
#  'Malta Drive-In',
#  'from the dance club definition',
#  'Voorhees',
#  "Papa John's",
#  'Northbound Lanes of 85',
#  'from my location',
#  'in Korean',
#  '99',
#  "Charlie is Jeff with you. I'd like to see what kind of resources we can put his way up here from Homeland",
#  'Christmas tree on fire',
#  '15',
#  'Corner Market design from now',
#  'Oklahoma',
#  'Cinebarre ready to go',
#  'do you have any',
#  '3.11',
#  'City Hall',
#  "everything you want I'm going I'm going to go there",
#  'Peter',
#  '24-hour 2491',
#  '2500 Ryan',
#  '3500 Ryan and Amanda Harvey from Frankfurt',
#  'show me a picture of a North Broad on Broad',
#  'KD advisor take your handle and all right refuse',
#  'still coming over everyone.',
#  'over here',
#  '1400 Walnut 1400 Walnut',
#  'Walnut',
#  'response team down here',
#  'put on your crown card',
#  '1400 Walnut',
#  'how many people were injured',
#  'how many injured as the Ritz-Carlton',
#  'procedure window vent tube',
#  '13th Street',
#  "yes ma'am medicine route to 700 Lombard",
#  'call Jennifer',
#  'recondition the Ritz-Carlton 105 is supposed to be at the Ritz-Carlton at this moment',
#  'we got a problem',
#  'okay to look at 13th and Walnut',
#  'Park City',
#  'Highway freedom',
#  'market and Juniper on the East portal',
#  'green Andy I need unit to go to Gordon hard they got the street like almost torn down',
#  'Duckhorn or Community radio we got a couple hundred people up on this phone',
#  'increase estrogen',
#  'Royals record',
#  'I got',
#  'on the roof of the building',
#  "what's the time",
#  'we have a light pole down right on the east east side',
#  'remove your area, comply so continuously',
#  'Zizek 9',
#  'supervisor',
#  'best relaxer',
#  'Vanessa Pascual Jack when you come in Center City on Market Street',
#  'rapid response Corps',
#  'Southeastern and worst case scenario they can get her over to the Firehouse she can get some kind of treatment',
#  'downtown FW ENFP ASAP',
#  'priority Brewing Ellsworth',
#  '31 route to East Point',
#  'going to California Berkeley Hardware Wilkesboro North',
#  'play teen sex',
#  '14 Oregon coast',
#  'location',
#  'Port Washington MSC',
#  "3500 Ryan's well all is quiet having check on you",
#  'Destiny Ortiz Columbus District',
#  'Operation Center monitoring this band for the movement',
#  'Mahoney Park',
#  '3400 rocker Brian',
#  'checkpoint and 3500 Ryan and Leon',
#  'if you ever need a ride or want we can take care of that for me',
#  'exploited Japanese shield shield for whoever I have',
#  'Southwest border',
#  'Charlie Charlie',
#  "looking for my partners news I don't see anything",
#  'cars going the wrong way on 16th Street',
#  'going the wrong way on gas tank on Miles',
#  'coming through to grab your bottles and cans in, please',
#  'do you have',
#  'X-rays and 15th going towards Drive',
#  'number for',
#  "it's right on the air",
#  'Arkansas',
#  'Southwest',
#  'Rick Ross',
#  'Franklin County Northbound right now',
#  'Arrangements in Hermitage',
#  'I need somebody original Heritage the traffic please',
#  'Herschel Jones Lenexa',
#  'just let me know James',
#  "I've already sent two teams down there I only have two left here and it's brown.",
#  '20 / 3500',
#  'keep on Front Street',
#  'go to Broad and Market',
#  '142',
#  'George Strait',
#  'the cars are coming through westbound lie a lot of people out here',
#  'Apostle Broken Arrow',
#  '22x Raider radio can you over North Central in 20 seconds I got a car available see if I can get somebody to court at 15th and Market firelighters trying to get through his having a really rough time',
#  'play Charlie A10 about 10 minutes or so',
#  'private dentist',
#  'Steve wires vernonburg they hurt a Leo',
#  '11 * 11',
#  'call tech support',
#  '3500 Ryan Columbus Republic Bank',
#  'let us know when her senior center city area',
#  'under control however street at South Penn Square and we probably has several thousand in the middle',
#  'directions',
#  'property',
#  'information about',
#  'Charlie Charlie',
#  '15th and Market',
#  'we have to go',
#  'Southpoint Apartments',
#  'only one over here.',
#  'everything I can work as long as I get some coffee',
#  'Paddington we have anything',
#  'New York',
#  'give me a call now',
#  'turn on 277 location',
#  'Rockin Jump',
#  'square square',
#  'have them come to the restaurant',
#  'printer',
#  'location Port Orange',
#  '100 South Broadway',
#  'okay',
#  '94 Gordon St Pomona East Side',
#  'give me a minute on heroin Jersey on and on',
#  'Savannah is Ron here of which Jersey on and green sweatpants',
#  'Asia 14th Avenue',
#  'corner',
#  'Down to Georgia',
#  'Pakwan Fremont',
#  "he's there on the pole in the AT&T Center Flyers",
#  'Candy Rain',
#  'and a night Mayfair Diner.',
#  'Springfield Mall',
#  'Minecraft war',
#  'Ivan personal AI Victoria radio',
#  'breaking yard either a liar',
#  'turkey wings',
#  'Riverdale',
#  'vehicles on Broad Street',
#  'we are closed on helmet right now before getting some resistance but I think we we we can muster enough horses to remove most of the crown out',
#  'explosion',
#  'coming to 15th and Market',
#  'Carnival city hall now',
#  'TV Guide',
#  'Seymour',
#  'alarm for the fire department',
#  "why didn't you see my text",
#  'Jennifer Hudson',
#  'Jersey and green sweatpants',
#  '1366',
#  'do you know what YouTube',
#  'washing machine is coming up here to Broad Street',
#  'Market Akron',
#  '905 South Street',
#  'can you have a car for free',
#  'call Sergio Campos people card for',
#  'Cromartie Street',
#  "where's my taxes",
#  'Cleveland High School',
#  'cardboard Square',
#  'Paul George',
#  'Barney Frank',
#  'number one number two',
#  'are unicorns in traffic court location location to Frankford and Tyson',
#  'no traffic coming through Cottman and erdrick',
#  'Johnny lever',
#  'suppose we have a pretty good',
#  'call 11 to Charlie two',
#  'Wells Fargo Walnut',
#  'call me auntie grandview New York YouTube',
#  'Highway Work summer car',
#  'moving down to Catherine Catherine Street Broad and Catherine',
#  'are they going to stop at the embassy building wait time',
#  'information',
#  'are you wanting to see your North End of City Hall on JFK',
#  'coming from Broad and what do you want them you coming towards City Hall',
#  'are lie angle thrown out here',
#  'Ronaldo head injury Harper',
#  'Remy Charlie 109 15th and Locust Street',
#  'my location',
#  'August 19th',
#  'Westminster Pike Market Street',
#  'Xbox in Locust VA ch',
#  'mx-11 Xfm',
#  'Stephen Root',
#  'Hardcore Pawn',
#  'Proverbs 14:1 location on 309',
#  'Kevin Costner',
#  'AC Moore',
#  "South Street b63 just making sure you're my window fans have a team or handmade",
#  'yeah can we get rescue to Broad and Lehigh about elderly male',
#  '415',
#  'Franklin Pike',
#  "I want a Slurpee officers on Frankford then we're going to have a SEPTA bus coming through North from Frankford Terminal 1 Frankfurt when it comes up they can let that bus come through and ate. It's pretty common",
#  'Frankford and Cottman',
#  'unfriended',
#  'state highway 3',
#  'Highway 3x in Murphy',
#  'sandwich makers game 3x',
#  'anyone from any one of location for me',
#  'square right',
#  'cortopassi 94',
#  'Stihl 16',
#  'fishing decorations',
#  '90490 Frankford and pricing is clear',
#  '12 + 1',
#  'so I want you to walk up for my location',
#  '15 blade traffic heavy traffic moderate leaving from over here yet or still here',
#  'acts 21',
#  'do I got to cook lake near for an assault',
#  "call Derrick Crowther North Broad everything's moving North clear we just making sure a concrete mixer and continue to push North",
#  "everything that you're pushing North is literally walking Northbound up for streetwear, dating back",
#  'chilling on ice',
#  'Patrol box truck',
#  'when you do get your people back on standby in Center City',
#  'crazy Genie sanitation or there is in a Caesar',
#  'torpor',
#  '4',
#  'make a call',
#  'breaking out windows that 1200',
#  '3.28',
#  'turn on can you make sure that your school uniform locations the window team window van team Jedi Juniper in Waukee',
#  'running more than what I have',
#  "we're here now but we need more units",
#  'over there now',
#  '34 Martin Avenue',
#  'Churchill funeral',
#  'all different version',
#  'just meet me at 402 Chestnut take that you down here with me',
#  'call 11.',
#  'Transformer rescue winners 1509 Chestnut Street',
#  'Courtney tattoo artist',
#  'call when would you love me',
#  '100 South Broadway',
#  'Lottery offices here and the rest of the other officers',
#  'Lego trucks to Juniper and Market',
#  '4 a.m.',
#  'broken window',
#  'Grandma walking up now',
#  "I'm going to head over to the 101 radio",
#  '80s rescue people flipping cars',
#  'Phoenix driving 160 market number one light blinking',
#  'scotus nominees under control or something',
#  'African Market',
#  'airport near here',
#  'location of this location',
#  'trying to knock it over',
#  'call Vivian V bar New Orleans',
#  "can we call that rescue and see if they're having trouble or anything get into law Nathan 101 please",
#  'head injury',
#  'Chestnut Pizza',
#  'at 1:50 market location',
#  '15th and Walnut St Market 15th and Walnut',
#  'in reference to the Ritz-Carlton incident can you please call the front desk for the incident please call front desk',
#  '13th and Berkeley',
#  'Vikings coming to meet me on the northeastern 03 home whenever you get this',
#  'call Walker on walking behind for westbound',
#  '1520 Verona Drive in wagons and start over 1520 Walnut',
#  '15th and Walnut',
#  '1528 Roanoke for Highway',
#  'call navient',
#  'Rite Aid 15th Street',
#  'count to 100',
#  'Lincoln 100 X Ray Ray Charles lyrics',
#  'Affairs appreciate your house rich house',
#  'thank you very much for the northeast corner and City Hall',
#  'Roy Schneider been waiting for a while',
#  'Bill Center City',
#  'copyright on my way',
#  'Broad and Snyder',
#  'State Police with the information of the problem',
#  'Taiwan comedy',
#  'working on this side a little bit',
#  'give me a call when it rains',
#  'California',
#  'grocery near me',
#  'Country Fair will be secured',
#  'Texas capital',
#  'believer',
#  '1818 Chestnut Old Navy for open property',
#  'Rio locations',
#  '1700 Chestnut',
#  'properties on location you said traffic lights are out of large part of 300',
#  'iMovies crab meat Lee off the air',
#  'PSA',
#  'Oregon Oregon Trail opening up',
#  'pick something all four corners on light poles down in clothes wire',
#  "children's you exact time right now",
#  'crossword',
#  'traffic on northbound traffic June 17th',
#  '18th and Chestnut traffic going eastbound and all Northbound 17th and Market traffic on northbound 17th and Market Market Transit',
#  'Walter location 18th and Chestnut',
#  'anaphylactic',
#  'Comedy House',
#  'iPhone 5',
#  '162nd',
#  'Metro 801',
#  'requesting a check over here at Justin is three different Austin warnings',
#  'call free',
#  "there's a fire engine on 16th Street",
#  'song it going to be on there now so I can go to block radio.',
#  'AR-15',
#  'retro Street from here',
#  'Verizon 360',
#  'traffic light',
#  'Charlie Levin you available for a call yeah give me a call now',
#  'Yuri self ready',
#  'traffic law improper',
#  "message to office Beaufort South to give an interview I'm okay with that",
#  'to me and thank you after I have them come from 16th and Chestnut and take 17th and Chestnut',
#  '17',
#  'how far we just have to 17th and Chestnut',
#  'call for damaged wall 16th and Chestnut',
#  'play some Colombian couple seconds',
#  'Charlie 11:03 please',
#  'weather on the north side',
#  'prison wagon',
#  'why is it green',
#  'Yak man I got a email this passed out on the treetop',
#  'Eastpoint',
#  'organic peppermint in your hair',
#  'Thursday morning universe and working',
#  '2418 e Broad and Sansom please',
#  'Northern Lehigh career points traffic',
#  'or give me a call',
#  'countdown on South Division',
#  'grocery',
#  'traffic map',
#  'Isaac for miniature All-City swim',
#  '3030',
#  'Pillsbury',
#  'Toyota Reno',
#  '3193 Oakley repair',
#  '15th and Market Soulful Corner Juniper and Market five nights now',
#  'call Queen Hearne OSU',
#  "is there working 12 to 8 on the details 12 to 8 unit you're not really clean 12 to 8.",
#  '12 Personnel you can resume member portal',
#  'Pio Pio near me',
#  'I feel pretty soundtrack',
#  'Robert 1402 Robert 1400 / 14.2',
#  'us11',
#  'Southwest Southwest',
#  'French lessons',
#  "Poncho's on Winnetka",
#  'will remain until the streets are clean and ready',
#  'call Venus William Powell in Times Square and Jerry bar',
#  "all right so wherever you guys were dropped off at make sure you congregate their Broad and South and that's where you were dropped off and if I should be coming to pick you up North Penn and Juniper",
#  '3rd Avenue and 8th Street 3rd Avenue and 8th Street',
#  '700 St Marks',
#  '2nd Avenue',
#  'how can I bet',
#  'highway highway 10 route',
#  'Cil',
#  'Brooklyn Bridge',
#  'mobile Field Force One audio',
#  'Tappan Zee Bridge',
#  'aicp',
#  'audio on the roadway',
#  'what direction',
#  'several hundred going westbound on 14th Street towards Union Square West from Union Square East',
#  'call Barclays ICP',
#  'go to three and four at 14th and 3rd',
#  'shopping district secure the shopping area',
#  'take the traffic on 6th Avenue',
#  'history',
#  'Auto Salvage',
#  "McCoy's",
#  '11267 South High Street',
#  'looking for on sale boys at 14th and 3rd grade need to know where to go',
#  'icp-oes',
#  'stop at 4th and Airport Way',
#  'car insurance',
#  'ICP on here',
#  'Volume 14 Union Square',
#  '2016 Tesla',
#  'Port Aransas restaurants',
#  '47',
#  'streatfeild avenue 64th avenue',
#  'projects for 4th grade',
#  '4 * 0',
#  'Days Inn 17th',
#  'Philly sound',
#  'Mia k',
#  'Pepsi or what',
#  'Walmart jobs',
#  'Capitol Hill Drive',
#  '1500 Broadway',
#  'Volkswagen 1959',
#  'a quarter of an ounce in the Northbound lanes are getting off the bridge',
#  'Brooklyn style CRV lieutenant',
#  'Houston Street',
#  'LaGuardia',
#  'Murano transmission',
#  'eicp',
#  'southbound FDR Drive.',
#  'celebration',
#  '7th Avenue South',
#  'location on 33rd Street',
#  'what is the location',
#  'what is conditioning',
#  'okay so what location',
#  '18 / 10',
#  'all units or city by one foot over the Citywide to or Unicity Y102',
#  'Citywide one switch over the city',
#  'Brooklyn',
#  'call Donald.',
#  'Brooklyn and Manhattan Depot switch over to Citywide to in regards to the process without a supervisor',
#  'RadioShack',
#  'Show Boat 1936',
#  'stationary Hoboken',
#  "westbound Southbound on the West Side Highway what's the location",
#  'walking in the traffic Lanes',
#  'going in and out of cars cars apart bass strings on southbound on the FDR',
#  'conditioner',
#  'Aquanaut tattoo',
#  'davor coin',
#  'Capricorn Jan 19th',
#  'probably about three or four hundred behind you',
#  'Brooklyn North',
#  'probably about 20 or 30',
#  '2101 Sanford',
#  'FDR Drive is about 123rd Street',
#  'Anastasia',
#  'Lariat truck 9851',
#  'directional',
#  '300 * 6',
#  't mobile number',
#  'Easton Court',
#  'Myrtle Willoughby',
#  '23rd Street',
#  'protesters',
#  '38 Special',
#  'marcellas',
#  'Livingston Southbound',
#  'Atlantic and 4th',
#  'the box that is waterproof',
#  'stop on 1st Avenue North',
#  "we haven't we haven't downtown where they all are at 5 and 4",
#  'Vicodin ES',
#  'are you at',
#  'gas station',
#  'Red Cliff',
#  'Vanderbilt Parkway',
#  "what's Donald Portsmouth brexit",
#  'Pontiac Cab',
#  '09',
#  '2371 6',
#  'wagon to 111 1154',
#  'accident',
#  "we need to make sure they're on one channel somebody we still roll call somehow",
#  '646',
#  'an elderly man and a son',
#  'call Park Lane',
#  '2325 2202',
#  'ball rolling',
#  'give me a mobile phone',
#  'cars acting suspicious',
#  '100 Avalon way',
#  'Morse High School',
#  'can I get stolen',
#  'breathing looks like maybe',
#  'call Judith all-district N64 the following announcement',
#  'contact the White Center to 640-2209',
#  'Channel 43',
#  'Charlie one five',
#  '12',
#  'Sephora',
#  'Guardian man Horton',
#  'Zuri',
#  '733 Ontario 31',
#  "OK Google will advisors Angela find out what's 1819 North 4th",
#  '45 W 60th Mile and Gratiot',
#  'number one female Hospital from 1111 Fulton Court 51083',
#  'viruses going today. The second one for a beauty salon tonight',
#  'Turn 4',
#  'volume for the alarm alarm',
#  'Closter 2288 forklift',
#  'cuz I got 130 KJR',
#  'handle 511',
#  'yes and just be advised this has no affiliation with any college or college party and there are green to turn maybe trying to attack right now',
#  'Opera',
#  'Sai temple',
#  'Franklin 44140 West Lafayette Kiara Mason at the Meyerhoff building students take he was robbed in for',
#  '5300 block of Cordelia softlayer',
#  'West 26th Street',
#  'temperature is what it is',
#  'restaurants on 207th Street',
#  'and 200 West Baltimore is THC Pharmacy',
#  'traffic',
#  ...]

# %%
'1 this is a bunny'.count('1')
# Out:
# 1

# %%
test = '3745 North Eddie'

# %%
re.findall(r'[1-9]+', test)
# Out:
# ['3745']

# %%
# Taking any numbers

number_identified = 0

for i in text_list:
    
    if re.findall(r'[0-9]+', i) != []:
#         print(f'{i}')
        
        number_identified += 1

print()
print(f'The number of Potential Addresses: {number_identified}')
# Out:
# The number of Potential Addresses: 354

# %%
# Taking numbers with a word following

number_identified = 0

for i in text_list:
    
    if re.findall(r'[0-9]+\s[A-z]+', i) != []:
        print(f'{i}')
        
        number_identified += 1

print()
print(f'The number of Potential Addresses: {number_identified}')
# Out:
# 20174 Perrysville
# p1191 Hyundai sedan
# 49047 to 49047
# 32 turn right 2013 Honda
# 41901 Mariposa
# 100-300 F4
# 30 years olds for Harrisonville tan jacket blue jeans
# California 665 Honda
# it does not open 901 mine it was from a VoIP phone named for
# for Juliet Romeo 297 2012 Nissan Rogue color red it comes out of Everett
# 365 nv20
# parking route 439 robber
# 1251 East Nelson Avenue District 2126
# 1531 Patrol
# Adam gilby 12279 California DL Baker 514-2791
# Channel 7 rescue 21 year old acting violent
# Tyrell on a wire rack in Westerville something exploded are in 1/2 hour butter down can I send anybody having an SNL
# 755 Boylston
# a company 4222 okay
# turn off the 106 Delta one 1303
# Mediacom 41182 Laguna Clay County Library 1 JFK Drive 41 1821 JFK Drive
# 21 Firethorn
# call Net10 105 with CPR at price to Airport Road
# call Kali Camaro R1 report Drive I want to keep oil Sinclair between editor and Fairfield
# 44531 pill
# 793 Boylston Street Dental Cairo
# set alarm at 1 alarm at 1
# negative at 1 tell my wife to call
# 715 Atlanta Deli
# can you take a retard 793 Boylston 793 Boylston St
# water company Boylston and Dartmouth and I'll send an additional engines that the alleyway xl44 oh
# 22 is also at the party are opposite corner of Boylston and Exeter
# St James Avery just got to get over to boil for 3 maybe to Boylston
# call Ilana 15 what is the location of Royal bigmans pizza
# take me to the airport by 11 to go to the JFK Library
# OK Google message Alyssa Hamilton 14 and ladder company one with you
# where do I go to 2933 for
# play 17 call Pilar 24
# 953 go ahead
# 67 Franklin
# 93803 two guys watch open mic
# oh 3 or is that the other agencies
# 14 form
# 1202 Franklin
# 1231 come in and pick up
# 1664 South Blue Island
# 712 West Diversey Apartments
# what's going on at 679 North Peoria
# set timer for 1 round 651
# character Warehouse service 3937 Parkcrest Street 39th and Lawrence Mass 116-117 to 8048 us-51
# 14 run the same truck work Anchorman
# 29 a fire alarm
# 3213 Harvard St
# 804 daleview
# 4626 and service
# 87 zombie themed parlor
# 21 and Hayes
# phone calling AT&T 2914 732 letter v
# 1110 highlands Plaza Drive East
# building 3937 Park Street at 39th and Lawrence 116 + 9.2 + 8
# 32 driver receive the message
# accounted for ovens automatically accounted for all members of 14 are accounted for
# 885 radio for information management is making the decision to put everyone out of the
# 58050 Beechtree Court
# 88888 John Cena
# Forever 21 in Yankee Candle
# 185 Adams
# 300 cars near 835 845
# 39243 Taco Bell
# 41 Whitney Point
# number 43 car
# call Page 39 what about a bus stop Cross Road
# 21 grapefruit
# 42 units on south field support the return to 4th and accept the portion and secure the four Baptist time
# call Battlefield 4 gas appointment tactical spacing
# f99 thank you
# 413 Arthur
# 2500 Ryan
# 3500 Ryan and Amanda Harvey from Frankfurt
# 1400 Walnut 1400 Walnut
# 1400 Walnut
# yes ma'am medicine route to 700 Lombard
# recondition the Ritz-Carlton 105 is supposed to be at the Ritz-Carlton at this moment
# 31 route to East Point
# 14 Oregon coast
# 3500 Ryan's well all is quiet having check on you
# 3400 rocker Brian
# checkpoint and 3500 Ryan and Leon
# 22x Raider radio can you over North Central in 20 seconds I got a car available see if I can get somebody to court at 15th and Market firelighters trying to get through his having a really rough time
# play Charlie A10 about 10 minutes or so
# 3500 Ryan Columbus Republic Bank
# turn on 277 location
# 100 South Broadway
# 94 Gordon St Pomona East Side
# 905 South Street
# call 11 to Charlie two
# mx-11 Xfm
# Proverbs 14:1 location on 309
# South Street b63 just making sure you're my window fans have a team or handmade
# I want a Slurpee officers on Frankford then we're going to have a SEPTA bus coming through North from Frankford Terminal 1 Frankfurt when it comes up they can let that bus come through and ate. It's pretty common
# 90490 Frankford and pricing is clear
# 15 blade traffic heavy traffic moderate leaving from over here yet or still here
# 34 Martin Avenue
# just meet me at 402 Chestnut take that you down here with me
# Transformer rescue winners 1509 Chestnut Street
# 100 South Broadway
# 4 a.m.
# I'm going to head over to the 101 radio
# Phoenix driving 160 market number one light blinking
# can we call that rescue and see if they're having trouble or anything get into law Nathan 101 please
# at 1:50 market location
# Vikings coming to meet me on the northeastern 03 home whenever you get this
# 1520 Verona Drive in wagons and start over 1520 Walnut
# 1528 Roanoke for Highway
# Lincoln 100 X Ray Ray Charles lyrics
# 1818 Chestnut Old Navy for open property
# 1700 Chestnut
# Charlie 11:03 please
# 2418 e Broad and Sansom please
# 3193 Oakley repair
# is there working 12 to 8 on the details 12 to 8 unit you're not really clean 12 to 8.
# 12 Personnel you can resume member portal
# Robert 1402 Robert 1400 / 14.2
# 700 St Marks
# highway highway 10 route
# 11267 South High Street
# Volume 14 Union Square
# 2016 Tesla
# 1500 Broadway
# probably about 20 or 30
# 2101 Sanford
# 38 Special
# we haven't we haven't downtown where they all are at 5 and 4
# 100 Avalon way
# call Judith all-district N64 the following announcement
# 733 Ontario 31
# OK Google will advisors Angela find out what's 1819 North 4th
# 45 W 60th Mile and Gratiot
# number one female Hospital from 1111 Fulton Court 51083
# Closter 2288 forklift
# cuz I got 130 KJR
# Franklin 44140 West Lafayette Kiara Mason at the Meyerhoff building students take he was robbed in for
# 5300 block of Cordelia softlayer
# and 200 West Baltimore is THC Pharmacy
# 45 m
# 300 North Charles
# Adderall use on 1 2 switch back to back today
# 118 North Highway
# 3 North Road
# 320 York Road from 320 York Road for the armed person at the BP in employment
# 16 North Holland
# I'm just inquiring if I had 2779 with dyspepsia
# 05 everything okay there
# MP3 download
# signal 30 at Moravia and Cold Springs also Harford and Coldspring same location
# 2016 worth
# 6011 cedonia unknown travel from anywhere
#
# The number of Potential Addresses: 157
