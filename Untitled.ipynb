# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('3_dataframes/df_speech_recognition.csv')
df.head()
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  /home/ubuntu/audio_files/Neal Manahan - negati...
# 1           1  /home/ubuntu/audio_files/Neal Manahan - negati...
# 2           2  /home/ubuntu/audio_files/Neal Manahan - negati...
# 3           3  /home/ubuntu/audio_files/Neal Manahan - negati...
# 4           4  /home/ubuntu/audio_files/Neal Manahan - negati...
#
#   good_exception audio_recognition
# 0      Exception               NaN
# 1      Exception               NaN
# 2      Exception               NaN
# 3      Exception               NaN
# 4      Exception               NaN

# %%
df['audio_recognition'].value_counts().sum()
# Out:
# 323

# %%
df.shape
# Out:
# (2898, 4)

# %%
pd.options.display.max_rows = 50

# %%
df['audio_recognition'].value_counts()
# Out:
# California                                                                                     3
# home                                                                                           2
# 83                                                                                             2
# call Connor                                                                                    2
# okay                                                                                           2
# control                                                                                        2
# call Cordy Glenn                                                                               1
# turn off alarm                                                                                 1
# set alarm for 5                                                                                1
# Fairfield Inn Express                                                                          1
# ...

# %%
df['audio_recognition'][0]
# Out:
# nan

# %%
df['audio_recognition'][5]
# Out:
# nan

# %%
for i in range(100):
    print(type(df['audio_recognition'][i]))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# file_name            object
# good_exception       object
# audio_recognition    object
# dtype: object

# %%
df.astype(str)
# Out:
#      Unnamed: 0                                          file_name  \
# 0             0  /home/ubuntu/audio_files/Neal Manahan - negati...
# 1             1  /home/ubuntu/audio_files/Neal Manahan - negati...
# 2             2  /home/ubuntu/audio_files/Neal Manahan - negati...
# 3             3  /home/ubuntu/audio_files/Neal Manahan - negati...
# 4             4  /home/ubuntu/audio_files/Neal Manahan - negati...
# 5             5  /home/ubuntu/audio_files/Neal Manahan - negati...
# 6             6  /home/ubuntu/audio_files/Neal Manahan - negati...
# 7             7  /home/ubuntu/audio_files/Neal Manahan - negati...
# 8             8  /home/ubuntu/audio_files/Neal Manahan - negati...
# 9             9  /home/ubuntu/audio_files/Neal Manahan - negati...
# 10           10  /home/ubuntu/audio_files/Neal Manahan - negati...
# 11           11  /home/ubuntu/audio_files/Neal Manahan - negati...
# 12           12  /home/ubuntu/audio_files/Neal Manahan - negati...
# ...

# %%
df['audio_recognition'] == 'NaN'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
#         ...
# 2873    False
# 2874    False
# 2875    False
# 2876    False
# 2877    False
# 2878    False
# 2879    False
# 2880    False
# 2881    False
# 2882    False
# 2883    False
# 2884    False
# 2885    False
# 2886    False
# 2887    False
# 2888    False
# 2889    False
# 2890    False
# 2891    False
# 2892    False
# 2893    False
# 2894    False
# 2895    False
# 2896    False
# 2897    False
# Name: audio_recognition, Length: 2898, dtype: bool
